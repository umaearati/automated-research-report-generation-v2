# %%
# gpt-4o-mini
# 1. select one llm model -  LLM-as-a-Judge ,Rule-based checks, Human evaluation

# %%
from pathlib import Path

report_path = Path("/Users/nanimahi/automated-research-report-generation/src/research_and_analyst/notebook/NIPS-2017-attention-is-all-you-need-Paper.pdf")

with open(report_path, "r") as f:
    report = f.read()

print(report[:500])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[1], line 6
#       3 report_path = Path("/Users/nanimahi/automated-research-report-generation/src/research_and_analyst/notebook/NIPS-2017-attention-is-all-you-need-Paper.pdf")
#       5 with open(report_path, "r") as f:
# ----> 6     report = f.read()
#       8 print(report[:500])
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x9c in position 4028: invalid start byte
